# %% [markdown]
# # API

# %% [markdown]
# ## Import packages

# %%
import json, requests # Libraries we need
import pandas as pd

# %% [markdown]
# ## Met Office API

# %%
mo_key   = "33b61cb4-e9ad-4b66-8a3d-fa9b322ba577"
mo_url   = "http://datapoint.metoffice.gov.uk/public/data/" # base URL
mo_ex = "val/wxobs/all/json/sitelist" # sites API URL
site_url = "val/wxobs/all/json/sitelist" # sites API URL

mopayload = {'key': mo_key} # Dictionary to hold request parameters
request = requests.get(mo_url + mo_ex, params=mopayload) # Do the request
request2 = request.json() # Capture the output

print(request2)
# Out:
# {'Locations': {'Location': [{'elevation': '7.0', 'id': '3066', 'latitude': '57.6494', 'longitude': '-3.5606', 'name': 'Kinloss', 'region': 'gr', 'unitaryAuthArea': 'Moray'}, {'elevation': '6.0', 'id': '3068', 'latitude': '57.712', 'longitude': '-3.322', 'obsSource': 'LNDSYN', 'name': 'Lossiemouth', 'region': 'gr', 'unitaryAuthArea': 'Moray'}, {'elevation': '36.0', 'id': '3075', 'latitude': '58.454', 'longitude': '-3.089', 'obsSource': 'LNDSYN', 'name': 'Wick John O Groats Airport', 'region': 'he', 'unitaryAuthArea': 'Highland'}, {'elevation': '15.0', 'id': '3002', 'latitude': '60.749', 'longitude': '-0.854', 'name': 'Baltasound', 'region': 'os', 'unitaryAuthArea': 'Shetland Islands'}, {'elevation': '82.0', 'id': '3005', 'latitude': '60.139', 'longitude': '-1.183', 'obsSource': 'LNDSYN', 'name': 'Lerwick (S. Screen)', 'region': 'os', 'unitaryAuthArea': 'Shetland Islands'}, {'elevation': '57.0', 'id': '3008', 'latitude': '59.527', 'longitude': '-1.628', 'name': 'Fair Isle', 'region': '
# ...

# %% [markdown]
# ## TFL API

# %%
tfl_key = "8e40bcafdcbe18c5ced0e89803e7d021"
tfl_url  = "https://api.tfl.gov.uk/" # base URL
tflpayload = {'key': tfl_key} # Dictionary to hold request parameters

# %% [markdown]
# ## Accidents request

# %%
acc1 = "/AccidentStats/2015" # sites API URL
acc2 = requests.get(api_url + accidents, params=payload) # Do the request
acc3 = acc2.json() # Capture the output

# %%
pd.DataFrame(acc3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-320dc0d3e6f0> in <module>
# ----> 1 pd.DataFrame(acc3)
#
# NameError: name 'acc3' is not defined

# %% [markdown]
# ## Roads request

# %%
roads1 = "Road" # sites API URL

roads2 = requests.get(api_url + roads1, params=payload) # Do the request
roadss3 = bikes2.json()
roads3
pd.DataFrame(roads3)
# Out:
#                                                 $type  \
# 0   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 1   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 2   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 3   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 4   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 5   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 6   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 7   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 8   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 9   Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 10  Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 11  Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 12  Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 13  Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 14  Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# 15  Tfl.Api.Presentation.Entities.RoadCorridor, Tf...
# ...

# %% [markdown]
# ## Journey planner request

# %%
jp1 = "/Journey/JourneyResults/{Seven Sisters Underground Station}/to/{Baker Street Underground Station}" # sites API URL

jp2 = requests.get(api_url + jp1, params=payload) # Do the request
jp3 = jp2.json()
jp3
# Out:
# {'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.ItineraryResult, Tfl.Api.Presentation.Entities',
#  'journeys': [{'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Journey, Tfl.Api.Presentation.Entities',
#    'startDateTime': '2019-03-02T17:35:00',
#    'duration': 19,
#    'arrivalDateTime': '2019-03-02T17:54:00',
#    'legs': [{'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Leg, Tfl.Api.Presentation.Entities',
#      'duration': 12,
#      'instruction': {'$type': 'Tfl.Api.Presentation.Entities.Instruction, Tfl.Api.Presentation.Entities',
#       'summary': 'Victoria line to Oxford Circus',
#       'detailed': 'Victoria line towards Brixton',
#       'steps': []},
#      'obstacles': [{'$type': 'Tfl.Api.Presentation.Entities.JourneyPlanner.Obstacle, Tfl.Api.Presentation.Entities',
#        'type': 'ESCALATOR',
#        'incline': 'UP',
#        'stopId': 1000173,
#        'position': 'AFTER'},
# ...

# %%
payload = {'key': api_key} # Dictionary to hold request parameters
s = requests.get(api_url + site_url, params=payload) # Do the request
sites = s.json() # Capture the output
